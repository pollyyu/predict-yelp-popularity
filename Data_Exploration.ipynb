# %%
# import relevant libraries
import pickle

# %%
with open('data_scraping/yelp_data.pickle','rb') as read_file:
    yelp_data = pickle.load(read_file)

# %%
yelp_data
# Out:
#                               name parentBusiness reviewCount  \
# 0            Mountain Mike’s Pizza           None          99
# 1            Fog Harbor Fish House           None        5705
# 2                        The House           None        4711
# 3   Farmhouse Kitchen Thai Cuisine           None        2149
# 4                   Dumpling House           None          56
# ..                             ...            ...         ...
# 26              Scoma’s Restaurant           None        3631
# 27                     Izakaya KOU           None         767
# 28  Pier Market Seafood Restaurant           None        1978
# 29  Nara Restaurant &amp; Sake Bar           None         982
# 30                   Blind Butcher           None          65
#
#                    neighborhoods  rating priceRange   formattedAddress  \
# 0                 [East Oakland]     0.0         $$       1448 High St
# 1            [Fisherman's Wharf]     4.0         $$            Pier 39
# ...
